# %% [markdown]
# *Reference*
# - [raghakot/keras-vis](https://github.com/raghakot/keras-vis)
#     - [keras-vis/examples](https://github.com/raghakot/keras-vis/tree/master/examples)
# - [How convolutional neural networks see the world](https://blog.keras.io/how-convolutional-neural-networks-see-the-world.html)
#     - [Twitter: Keras-vis: a toolbox for visualizing what goes on inside a deep learning model](https://twitter.com/fchollet/status/879079716359221249)
# - [Quiver: Interactive convnet features visualization for Keras](https://github.com/keplr-io/quiver)
