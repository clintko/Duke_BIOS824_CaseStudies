# %% [markdown]
# # About the notebook

# %%
# !ls
# Out:
# gdrive	mazurowski_lab_2017_08.jpg  mnist_cnn.py  sample_data

# %%
# !ls /content
# Out:
# gdrive	mazurowski_lab_2017_08.jpg  mnist_cnn.py  sample_data

# %% [markdown]
# The location of my github folder

# %%
# !ls -l 'gdrive/My Drive/Colab Notebooks/Duke_BIOS824_CaseStudies'
# Out:
# total 1391
# drwx------ 2 root root    4096 Jan 19 22:40 figures
# -rw------- 1 root root 1190449 Jan 19 22:40 hw01_image_apply_linear_filter.ipynb
# -rw------- 1 root root    1734 Jan 19 23:28 mod01_hw02_CNN_overtrain.ipynb
# -rw------- 1 root root  226139 Jan 19 23:26 mod01_lec02_cnn_mnist.ipynb
# -rw------- 1 root root      61 Jan 19 22:40 README.md

# %% [markdown]
# # Decomposed the code mnist_cnn.py

# %%
# !cat mnist_cnn.py
# Out:
# '''Trains a simple convnet on the MNIST dataset.
#
# Gets to 99.25% test accuracy after 12 epochs
# (there is still a lot of margin for parameter tuning).
# 16 seconds per epoch on a GRID K520 GPU.
# '''
#
# from __future__ import print_function
# import keras
# from keras.datasets import mnist
# from keras.models import Sequential
# from keras.layers import Dense, Dropout, Flatten
# from keras.layers import Conv2D, MaxPooling2D
# from keras import backend as K
#
# batch_size = 128
# num_classes = 10
# epochs = 12
#
# # input image dimensions
# img_rows, img_cols = 28, 28
#
# # the data, split between train and test sets
# (x_train, y_train), (x_test, y_test) = mnist.load_data()
#
# if K.image_data_format() == 'channels_first':
#     x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
#     x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
#     input_shape = (1, img_rows, img_cols)
# else:
# ...
