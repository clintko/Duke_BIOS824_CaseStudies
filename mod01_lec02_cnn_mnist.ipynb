# %% [markdown]
# # About the notebook
# Code from the slide

# %% [markdown]
# ```
# print("hello")
#
# !pip install keras scikit-learn imbalanced-learn
#
# import numpy
#
# import keras
# from keras import applications
#
# !wget http://deckard.duhs.duke.edu/~mazurowski/images/mazurowski_lab_2017_08.jpg
#
# !ls
#
# # %matplotlib inline
# # the percent is for it to be run by the notebook, not command or shell
#
# import matplotlib.pyplot as plt
# # if I want to to import to the main main namespace, I would write from matplotlib.pyplot import * (for all functions or specific function instead of *)
#
# from keras.preprocessing import image #to import library for reading images
#
# img = image.load_img("mazurowski_lab_2017_08.jpg", target_size = (200,200))
# img2 = image.load_img("mazurowski_lab_2017_08.jpg")
# plt.imshow(img2)
#
# !ls -l sample_data
#
# !wget https://raw.githubusercontent.com/keras-team/keras/master/examples/mnist_cnn.py
#
# !ls
#
# # !rm mnist_cnn.py mnist_cnn.py.1
# # removes files
#
# !python mnist_cnn.py
#
# !cat mnist_cnn.py #prints the content of the file
#
# #remember you need to create the
# # fit_of_the_model object
# plt.plot(fit_of_the_model.history["val_loss"])
# ```

# %%
print("hello")
# Out:
# hello

# %%
# !pip install keras scikit-learn imbalanced-learn

# %%
### import libraris
import numpy

import keras
from keras import applications
from keras.preprocessing import image #to import library for reading images

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
# !wget http://deckard.duhs.duke.edu/~mazurowski/images/mazurowski_lab_2017_08.jpg
# Out:
# --2019-01-19 23:18:13--  http://deckard.duhs.duke.edu/~mazurowski/images/mazurowski_lab_2017_08.jpg
# Resolving deckard.duhs.duke.edu (deckard.duhs.duke.edu)... 152.16.96.73
# Connecting to deckard.duhs.duke.edu (deckard.duhs.duke.edu)|152.16.96.73|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 534974 (522K) [image/jpeg]
# Saving to: ‘mazurowski_lab_2017_08.jpg’
#
# mazurowski_lab_2017 100%[===================>] 522.44K  3.03MB/s    in 0.2s
#
# 2019-01-19 23:18:14 (3.03 MB/s) - ‘mazurowski_lab_2017_08.jpg’ saved [534974/534974]

# %%
# !ls
# Out:
# gdrive	mazurowski_lab_2017_08.jpg  sample_data

# %%
# !ls -l sample_data
# Out:
# total 55504
# -r-xr-xr-x 1 root root     1697 Jan  1  2000 anscombe.json
# -rw-r--r-- 1 root root   301141 Jan  8 17:14 california_housing_test.csv
# -rw-r--r-- 1 root root  1706430 Jan  8 17:14 california_housing_train.csv
# -rw-r--r-- 1 root root 18289443 Jan  8 17:15 mnist_test.csv
# -rw-r--r-- 1 root root 36523880 Jan  8 17:15 mnist_train_small.csv
# -r-xr-xr-x 1 root root      903 Jan  1  2000 README.md

# %%
img = image.load_img("mazurowski_lab_2017_08.jpg", target_size = (200,200))
img2 = image.load_img("mazurowski_lab_2017_08.jpg")
plt.imshow(img2)

# %%
# !wget https://raw.githubusercontent.com/keras-team/keras/master/examples/mnist_cnn.py
# Out:
# --2019-01-19 23:18:37--  https://raw.githubusercontent.com/keras-team/keras/master/examples/mnist_cnn.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2257 (2.2K) [text/plain]
# Saving to: ‘mnist_cnn.py’
#
# mnist_cnn.py        100%[===================>]   2.20K  --.-KB/s    in 0s
#
# 2019-01-19 23:18:38 (57.8 MB/s) - ‘mnist_cnn.py’ saved [2257/2257]

# %%
# !ls -1
# Out:
# gdrive
# mazurowski_lab_2017_08.jpg
# mnist_cnn.py
# sample_data

# %%
# !python mnist_cnn.py
# Out:
# Using TensorFlow backend.
# ...
# 11493376/11490434 [==============================] - 0s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/12
# 2019-01-19 23:18:47.823777: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-01-19 23:18:47.824178: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2019-01-19 23:18:47.824212: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2019-01-19 23:18:48.760301: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# ...

# %%
# remember you need to create the 
# fit_of_the_model object
plt.plot(fit_of_the_model.history["val_loss"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-155f61c49b56> in <module>()
# ----> 1 plt.plot(fit_of_the_model.history["val_loss"])
#
# NameError: name 'fit_of_the_model' is not defined
